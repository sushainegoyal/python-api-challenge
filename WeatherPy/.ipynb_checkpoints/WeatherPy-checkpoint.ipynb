# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import json
import os as os
import matplotlib.pyplot as plt
import csv as csv

# Import API key
from api_keys import api_key

# !pip install citipy

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# Collecting citipy
#   Downloading https://files.pythonhosted.org/packages/3b/d0/59721d0f3954781488aac17ee4a40412d0a3547e98bb16377a09c39a2807/citipy-0.0.5.tar.gz (557kB)
# Collecting kdtree>=0.12 (from citipy)
#   Downloading https://files.pythonhosted.org/packages/00/3d/bd727d025b1706798aae14da3f69fc7d5a8639dc9e0eba37c7dcd43eb03e/kdtree-0.16-py2.py3-none-any.whl
# Building wheels for collected packages: citipy
#   Building wheel for citipy (setup.py): started
#   Building wheel for citipy (setup.py): finished with status 'done'
#   Stored in directory: C:\Users\susha\AppData\Local\pip\Cache\wheels\6f\07\0d\0392639cf1c10376f59decd06775c0e085ca2458c6036c1028
# Successfully built citipy
# Installing collected packages: kdtree, citipy
# Successfully installed citipy-0.0.5 kdtree-0.16

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print('''Beginning Data Retrieval     
-----------------------------''')

url = "http://api.openweathermap.org/data/2.5/weather?"
record_num = 0
set_num = 1
city_info = []

for city in cities:
    query_url = url + "appid=" + api_key + "&q=" + city
    weather_response = requests.get(query_url)
    weather_json = weather_response.json()
    
    try:
        record_num += 1
        latitude = weather_json["coord"]["lat"]
        temperature = weather_json["main"]["temp"]
        humidity = weather_json["main"]["humidity"]
        cloudiness = weather_json["clouds"]["all"]
        wind_speed = weather_json["wind"]["speed"]
        city_info.append({"Name": city, "Latitude": latitude, "Temperature (F)": temperature, "Humidity (%)": humidity, 
                          "Cloudiness (%)": cloudiness, "Wind Speed (mph)": wind_speed})
        print(f"Processing Record {record_num} of Set {set_num} | {city}")
    
    except KeyError: 
        cities.remove(city)
        record_num = 0
        set_num += 1
        print("City not found. Skipping...")
        pass
    
print('''-----------------------------
Data Retrieval Complete      
-----------------------------''')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ziro
# Processing Record 2 of Set 1 | kidal
# Processing Record 3 of Set 1 | luderitz
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | edd
# Processing Record 7 of Set 1 | hobart
# City not found. Skipping...
# Processing Record 1 of Set 2 | los llanos de aridane
# Processing Record 2 of Set 2 | mangrol
# City not found. Skipping...
# Processing Record 1 of Set 3 | ilulissat
# Processing Record 2 of Set 3 | hithadhoo
# Processing Record 3 of Set 3 | punta arenas
# City not found. Skipping...
# Processing Record 1 of Set 4 | opuwo
# Processing Record 2 of Set 4 | bredasdorp
# Processing Record 3 of Set 4 | port shepstone
# Processing Record 4 of Set 4 | rikitea
# Processing Record 5 of Set 4 | castro
# Processing Record 6 of Set 4 | rundu
# Processing Record 7 of Set 4 | port alfred
# Processing Record 8 of Set 4 | busselton
# Processing Record 9 of Set 4 | avarua
# Processing Record 10 of Set 4 | ushuaia
# Processing Record 11 of Set 4 | flinders
# Processing Record 12 of Set 4 | bluff
# City not found. Skipping...
# Processing Record 1 of Set 5 | el nispero
# Processing Record 3 of Set 16 | pachelma
# Processing Record 4 of Set 16 | toyooka
# Processing Record 5 of Set 16 | saint george
# Processing Record 6 of Set 16 | san patricio
# Processing Record 7 of Set 16 | marabba
# Processing Record 8 of Set 16 | koflach
# Processing Record 9 of Set 16 | arcata
# Processing Record 10 of Set 16 | saint-philippe
# City not found. Skipping...
# Processing Record 1 of Set 17 | kaitangata
# Processing Record 2 of Set 17 | sainte-martine
# Processing Record 3 of Set 17 | khasan
# Processing Record 4 of Set 17 | erdenet
# Processing Record 5 of Set 17 | alta floresta
# Processing Record 6 of Set 17 | comodoro rivadavia
# Processing Record 7 of Set 17 | sitka
# Processing Record 8 of Set 17 | port lincoln
# Processing Record 9 of Set 17 | razdolnoye
# City not found. Skipping...
# Processing Record 1 of Set 18 | klaksvik
# Processing Record 2 of Set 18 | isangel
# Processing Record 3 of Set 18 | kahului
# Processing Record 4 of Set 18 | conceicao do araguaia
# Processing Record 5 of Set 18 | cururupu
# Processing Record 6 of Set 18 | srandakan
# Processing Record 7 of Set 18 | kiama
# Processing Record 8 of Set 18 | eureka
# Processing Record 9 of Set 18 | fort nelson
# Processing Record 10 of Set 18 | iqaluit
# City not found. Skipping...
# Processing Record 1 of Set 19 | saint anthony
# Processing Record 2 of Set 19 | qandala
# Processing Record 3 of Set 19 | thompson
# Processing Record 4 of Set 19 | nanortalik
# Processing Record 5 of Set 19 | kudahuvadhoo
# Processing Record 6 of Set 19 | vila franca do campo
# Processing Record 7 of Set 19 | san pedro
# Processing Record 8 of Set 19 | saldanha
# Processing Record 9 of Set 19 | muncar
# Processing Record 10 of Set 19 | half moon bay
# Processing Record 11 of Set 19 | shizunai
# Processing Record 12 of Set 19 | erenhot
# Processing Record 13 of Set 19 | port elizabeth
# Processing Record 14 of Set 19 | chuy
# Processing Record 15 of Set 19 | saint-pierre
# Processing Record 16 of Set 19 | itanhem
# City not found. Skipping...
# Processing Record 1 of Set 20 | san pedro de ycuamandiyu
# City not found. Skipping...
# Processing Record 1 of Set 21 | tautira
# Processing Record 2 of Set 21 | necochea
# Processing Record 3 of Set 21 | acapulco
# Processing Record 4 of Set 21 | pszczyna
# Processing Record 5 of Set 21 | tansen
# Processing Record 6 of Set 21 | faanui
# Processing Record 7 of Set 21 | lyaskelya
# Processing Record 8 of Set 21 | santo tomas
# Processing Record 9 of Set 21 | nacogdoches
# Processing Record 10 of Set 21 | teluknaga
# Processing Record 11 of Set 21 | riberalta
# Processing Record 12 of Set 21 | maceio
# Processing Record 13 of Set 21 | harper
# Processing Record 14 of Set 21 | vao
# Processing Record 15 of Set 21 | springbok
# Processing Record 16 of Set 21 | bijar
# Processing Record 17 of Set 21 | ahipara
# Processing Record 18 of Set 21 | la paz
# Processing Record 19 of Set 21 | zaozerne
# Processing Record 20 of Set 21 | umarkot
# Processing Record 21 of Set 21 | husavik
# Processing Record 22 of Set 21 | cabo san lucas
# Processing Record 23 of Set 21 | fare
# Processing Record 24 of Set 21 | rosarito
# City not found. Skipping...
# Processing Record 1 of Set 22 | taunggyi
# Processing Record 2 of Set 22 | lavrentiya
# Processing Record 3 of Set 22 | atasu
# Processing Record 4 of Set 22 | bethel
# Processing Record 5 of Set 22 | salalah
# Processing Record 6 of Set 22 | tuatapere
# Processing Record 7 of Set 22 | naraini
# City not found. Skipping...
# Processing Record 1 of Set 23 | statesboro
# City not found. Skipping...
# Processing Record 1 of Set 24 | georgetown
# Processing Record 2 of Set 24 | ljungby
# City not found. Skipping...
# Processing Record 1 of Set 25 | birao
# Processing Record 2 of Set 25 | miranda
# Processing Record 3 of Set 25 | carauari
# Processing Record 4 of Set 25 | raudeberg
# Processing Record 5 of Set 25 | rio gallegos
# Processing Record 6 of Set 25 | puerto ayora
# City not found. Skipping...
# Processing Record 1 of Set 26 | shaunavon
# Processing Record 2 of Set 26 | wyndham
# Processing Record 3 of Set 26 | auki
# Processing Record 4 of Set 26 | coxim
# Processing Record 5 of Set 26 | palmer
# Processing Record 6 of Set 26 | longyearbyen
# Processing Record 7 of Set 26 | ambon
# City not found. Skipping...
# Processing Record 1 of Set 27 | carnarvon
# Processing Record 2 of Set 27 | son la
# Processing Record 3 of Set 27 | enshi
# Processing Record 4 of Set 27 | miramar
# Processing Record 5 of Set 27 | buraydah
# City not found. Skipping...
# Processing Record 1 of Set 28 | port blair
# Processing Record 2 of Set 28 | rocha
# Processing Record 3 of Set 28 | eyl
# Processing Record 4 of Set 28 | grindavik
# Processing Record 5 of Set 28 | komsomolskiy
# Processing Record 6 of Set 28 | khatanga
# Processing Record 7 of Set 28 | jinchang
# City not found. Skipping...
# Processing Record 1 of Set 29 | olpad
# City not found. Skipping...
# Processing Record 1 of Set 30 | muroto
# Processing Record 2 of Set 30 | souillac
# Processing Record 3 of Set 30 | creston
# Processing Record 4 of Set 30 | batemans bay
# City not found. Skipping...
# Processing Record 1 of Set 31 | henties bay
# Processing Record 2 of Set 31 | ondjiva
# Processing Record 3 of Set 31 | contamana
# Processing Record 4 of Set 31 | kedgwick
# Processing Record 5 of Set 31 | san pedro de uraba
# Processing Record 6 of Set 31 | saint-augustin
# Processing Record 7 of Set 31 | dubbo
# City not found. Skipping...
# Processing Record 1 of Set 32 | the valley
# Processing Record 2 of Set 32 | bambous virieux
# Processing Record 3 of Set 32 | vittoria
# Processing Record 4 of Set 32 | egvekinot
# Processing Record 5 of Set 32 | daitari
# Processing Record 6 of Set 32 | nelson bay
# City not found. Skipping...
# Processing Record 1 of Set 33 | pimentel
# Processing Record 2 of Set 33 | ruston
# City not found. Skipping...
# Processing Record 1 of Set 34 | kindu
# City not found. Skipping...
# Processing Record 1 of Set 35 | bilma
# Processing Record 2 of Set 35 | darhan
# Processing Record 3 of Set 35 | rajsamand
# Processing Record 4 of Set 35 | jiancheng
# Processing Record 5 of Set 35 | sao filipe
# Processing Record 6 of Set 35 | mbaiki
# Processing Record 7 of Set 35 | mocuba
# Processing Record 8 of Set 35 | toora-khem
# City not found. Skipping...
# Processing Record 1 of Set 36 | dikson
# Processing Record 2 of Set 36 | sept-iles
# Processing Record 3 of Set 36 | cayenne
# Processing Record 4 of Set 36 | boende
# Processing Record 5 of Set 36 | yarmouth
# Processing Record 6 of Set 36 | itarema
# Processing Record 7 of Set 36 | brownsville
# Processing Record 8 of Set 36 | yellowknife
# Processing Record 9 of Set 36 | smiltene
# Processing Record 10 of Set 36 | luanda
# Processing Record 11 of Set 36 | poum
# Processing Record 12 of Set 36 | beringovskiy
# Processing Record 13 of Set 36 | cap malheureux
# Processing Record 14 of Set 36 | weatherford
# Processing Record 15 of Set 36 | yulara
# Processing Record 16 of Set 36 | wasilla
# City not found. Skipping...
# Processing Record 1 of Set 37 | marseille
# Processing Record 2 of Set 37 | homer
# Processing Record 3 of Set 37 | mackay
# Processing Record 4 of Set 37 | alberton
# Processing Record 5 of Set 37 | waddan
# Processing Record 6 of Set 37 | kirakira
# Processing Record 7 of Set 37 | tavrichanka
# Processing Record 8 of Set 37 | vanimo
# Processing Record 9 of Set 37 | price
# Processing Record 10 of Set 37 | wilmington
# Processing Record 11 of Set 37 | mount isa
# City not found. Skipping...
# Processing Record 1 of Set 38 | narsaq
# Processing Record 2 of Set 38 | bontang
# Processing Record 3 of Set 38 | tiksi
# City not found. Skipping...
# Processing Record 1 of Set 39 | tual
# Processing Record 2 of Set 39 | djambala
# Processing Record 3 of Set 39 | portland
# Processing Record 4 of Set 39 | ancud
# Processing Record 5 of Set 39 | sioux lookout
# City not found. Skipping...
# Processing Record 1 of Set 40 | paamiut
# Processing Record 2 of Set 40 | hidalgo
# Processing Record 3 of Set 40 | sao felix do xingu
# Processing Record 4 of Set 40 | keti bandar
# Processing Record 5 of Set 40 | sur
# Processing Record 6 of Set 40 | prince george
# Processing Record 7 of Set 40 | turayf
# Processing Record 8 of Set 40 | foumban
# Processing Record 9 of Set 40 | mamou
# Processing Record 10 of Set 40 | galesong
# Processing Record 11 of Set 40 | manggar
# Processing Record 12 of Set 40 | victoria
# Processing Record 13 of Set 40 | pokrovka
# Processing Record 14 of Set 40 | hovd
# Processing Record 15 of Set 40 | krasnik
# Processing Record 16 of Set 40 | skjervoy
# Processing Record 17 of Set 40 | miandrivazo
# Processing Record 18 of Set 40 | orlik
# Processing Record 19 of Set 40 | las margaritas
# Processing Record 20 of Set 40 | preobrazheniye
# Processing Record 21 of Set 40 | adrar
# Processing Record 22 of Set 40 | nhulunbuy
# Processing Record 23 of Set 40 | tura
# Processing Record 24 of Set 40 | xinqing
# Processing Record 25 of Set 40 | bathsheba
# Processing Record 26 of Set 40 | oltu
# Processing Record 27 of Set 40 | nambucca heads
# City not found. Skipping...
# Processing Record 1 of Set 41 | liberal
# City not found. Skipping...
# Processing Record 1 of Set 42 | chizhou
# Processing Record 2 of Set 42 | tupelo
# Processing Record 3 of Set 42 | jamui
# City not found. Skipping...
# Processing Record 1 of Set 43 | burns lake
# Processing Record 2 of Set 43 | changli
# Processing Record 3 of Set 50 | norman wells
# Processing Record 4 of Set 50 | tarbes
# Processing Record 5 of Set 50 | brigantine
# Processing Record 6 of Set 50 | hinton
# Processing Record 7 of Set 50 | marienburg
# Processing Record 8 of Set 50 | waipawa
# Processing Record 9 of Set 50 | sindou
# Processing Record 10 of Set 50 | coihaique
# Processing Record 11 of Set 50 | ukiah
# Processing Record 12 of Set 50 | jucas
# Processing Record 13 of Set 50 | dongsheng
# Processing Record 14 of Set 50 | kanniyakumari
# Processing Record 15 of Set 50 | llanes
# Processing Record 16 of Set 50 | benguela
# Processing Record 17 of Set 50 | pasighat
# Processing Record 18 of Set 50 | kyzyl-suu
# Processing Record 19 of Set 50 | gbarnga
# Processing Record 20 of Set 50 | abha
# Processing Record 21 of Set 50 | zhengjiatun
# Processing Record 22 of Set 50 | canutama
# Processing Record 23 of Set 50 | calabozo
# Processing Record 24 of Set 50 | cayhagan
# Processing Record 25 of Set 50 | ferma
# Processing Record 26 of Set 50 | calama
# Processing Record 27 of Set 50 | pierre
# Processing Record 28 of Set 50 | mumford
# Processing Record 29 of Set 50 | nishihara
# Processing Record 30 of Set 50 | chapais
# Processing Record 31 of Set 50 | espanola
# Processing Record 32 of Set 50 | harwich
# Processing Record 33 of Set 50 | aleppo
# Processing Record 34 of Set 50 | magangue
# Processing Record 35 of Set 50 | lorengau
# Processing Record 36 of Set 50 | neiafu
# Processing Record 37 of Set 50 | khandyga
# Processing Record 38 of Set 50 | touros
# Processing Record 39 of Set 50 | rio grande
# Processing Record 40 of Set 50 | arlit
# Processing Record 41 of Set 50 | dhadar
# Processing Record 42 of Set 50 | visby
# Processing Record 43 of Set 50 | hami
# Processing Record 44 of Set 50 | jiuquan
# Processing Record 45 of Set 50 | solnechnyy
# Processing Record 46 of Set 50 | gezing
# Processing Record 47 of Set 50 | kuybyshevskiy zaton
# Processing Record 48 of Set 50 | tilichiki
# Processing Record 49 of Set 50 | witu
# Processing Record 50 of Set 50 | makarov
# Processing Record 51 of Set 50 | hirara
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 of Set 52 | trabzon
# Processing Record 2 of Set 52 | birobidzhan
# Processing Record 3 of Set 52 | griffith
# Processing Record 4 of Set 52 | santiago
# Processing Record 5 of Set 52 | miri
# City not found. Skipping...
# Processing Record 1 of Set 53 | bandarbeyla
# Processing Record 2 of Set 53 | bamiantong
# Processing Record 3 of Set 53 | baley
# Processing Record 4 of Set 53 | monroe
# Processing Record 5 of Set 53 | sinop
# Processing Record 6 of Set 53 | virginia beach
# Processing Record 7 of Set 53 | katol
# Processing Record 8 of Set 53 | hofn
# City not found. Skipping...
# Processing Record 1 of Set 54 | okitipupa
# City not found. Skipping...
# Processing Record 1 of Set 55 | college
# Processing Record 2 of Set 55 | omboue
# Processing Record 3 of Set 55 | camalu
# City not found. Skipping...
# Processing Record 1 of Set 56 | cockburn town
# Processing Record 2 of Set 56 | kokopo
# Processing Record 3 of Set 56 | eydhafushi
# Processing Record 4 of Set 56 | skelleftea
# Processing Record 5 of Set 56 | zonguldak
# Processing Record 6 of Set 56 | terekli-mekteb
# Processing Record 7 of Set 56 | hamilton
# Processing Record 8 of Set 56 | miechow
# Processing Record 9 of Set 56 | turukhansk
# Processing Record 10 of Set 56 | oussouye
# Processing Record 11 of Set 56 | vestmannaeyjar
# Processing Record 12 of Set 56 | imeni poliny osipenko
# Processing Record 13 of Set 56 | les escoumins
# City not found. Skipping...
# Processing Record 1 of Set 57 | qaqortoq
# Processing Record 2 of Set 57 | swift current
# Processing Record 3 of Set 57 | quatre cocos
# Processing Record 4 of Set 57 | krasnorechenskiy
# Processing Record 5 of Set 57 | bilibino
# Processing Record 6 of Set 57 | altamira
# Processing Record 7 of Set 57 | pangkalanbuun
# Processing Record 8 of Set 57 | anori
# City not found. Skipping...
# Processing Record 1 of Set 58 | aktau
# Processing Record 2 of Set 58 | muravlenko
# Processing Record 3 of Set 58 | bahile
# Processing Record 4 of Set 58 | fortuna
# Processing Record 5 of Set 58 | nampula
# Processing Record 6 of Set 58 | muisne
# Processing Record 7 of Set 58 | itaituba
# Processing Record 8 of Set 58 | maiduguri
# Processing Record 9 of Set 58 | la ronge
# Processing Record 10 of Set 58 | chabahar
# Processing Record 11 of Set 58 | ocos
# City not found. Skipping...
# Processing Record 1 of Set 59 | rantauprapat
# Processing Record 2 of Set 59 | yuanli
# Processing Record 3 of Set 59 | ulladulla
# Processing Record 4 of Set 59 | carutapera
# Processing Record 5 of Set 59 | bonavista
# Processing Record 6 of Set 59 | macas
# Processing Record 7 of Set 59 | mujiayingzi
# Processing Record 8 of Set 59 | dieppe
# Processing Record 9 of Set 59 | lakatoro
# Processing Record 10 of Set 59 | ilam
# Processing Record 11 of Set 59 | sinnamary
# Processing Record 12 of Set 59 | vostok
# Processing Record 13 of Set 59 | wajid
# Processing Record 14 of Set 59 | tuban
# Processing Record 15 of Set 59 | maracacume
# City not found. Skipping...
# Processing Record 1 of Set 60 | manuk mangkaw
# Processing Record 2 of Set 60 | paulista
# Processing Record 3 of Set 60 | kieta
# Processing Record 4 of Set 60 | laiyang
# Processing Record 5 of Set 60 | diplo
# Processing Record 6 of Set 60 | mustasaari
# Processing Record 7 of Set 60 | ko samui
# Processing Record 8 of Set 60 | bayan
# Processing Record 9 of Set 60 | kalat
# Processing Record 10 of Set 60 | putina
# Processing Record 11 of Set 60 | point fortin
# Processing Record 12 of Set 60 | helong
# Processing Record 13 of Set 60 | kifri
# Processing Record 14 of Set 60 | aizkraukle
# Processing Record 15 of Set 60 | constitucion
# Processing Record 16 of Set 60 | angoche
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Testing API Key 
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = url + "appid=" + api_key + "&q=London"
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=6131d7898e36c520d9dfd5c59aaab33e&q=London

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create dataframe
weather_df = pd.DataFrame(city_info)

# Write to CSV 
weather_df.to_csv("../cities.csv")

# Display the top 5-10 values of the dataframe
weather_df.head(10)
# Out:
#    Cloudiness (%)  Humidity (%)  Latitude                   Name  \
# 0              53            86     27.54                   ziro
# 1               0            18     18.44                  kidal
# 2             100            82    -26.65               luderitz
# 3              20            49    -42.78            new norfolk
# 4              88            90     15.34                  vaini
# 5               0            33     13.93                    edd
# 6              20            55    -42.88                 hobart
# 7              32            83     28.66  los llanos de aridane
# 8               6            49     25.33                mangrol
# 9              99            61     69.22              ilulissat
#
#    Temperature (F)  Wind Speed (mph)
# 0           286.46              1.65
# 1           296.81              0.99
# 2           289.15              4.60
# 3           286.55              6.20
# 4           293.69              1.34
# 5           302.24              0.81
# 6           286.55              6.20
# 7           293.23              7.20
# 8           294.32              2.05
# 9           265.52              2.19

# %%
# Filtering data to remove "outliers" (Values greater than 100%)
weather_df = weather_df[weather_df["Humidity (%)"] <= 100]
weather_df.head(10)
# Out:
#    Cloudiness (%)  Humidity (%)  Latitude                   Name  \
# 0              53            86     27.54                   ziro
# 1               0            18     18.44                  kidal
# 2             100            82    -26.65               luderitz
# 3              20            49    -42.78            new norfolk
# 4              88            90     15.34                  vaini
# 5               0            33     13.93                    edd
# 6              20            55    -42.88                 hobart
# 7              32            83     28.66  los llanos de aridane
# 8               6            49     25.33                mangrol
# 9              99            61     69.22              ilulissat
#
#    Temperature (F)  Wind Speed (mph)
# 0           286.46              1.65
# 1           296.81              0.99
# 2           289.15              4.60
# 3           286.55              6.20
# 4           293.69              1.34
# 5           302.24              0.81
# 6           286.55              6.20
# 7           293.23              7.20
# 8           294.32              2.05
# 9           265.52              2.19

# %%
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     lompoc           1      US  1534984500        44  34.64 -120.46
# 1   klaksvik          92      FO  1534983600       100  62.23   -6.59
# 2  bisignano           0      IT  1534981800        88  39.50   16.27
# 3       hilo          90      US  1534984860        90  19.71 -155.08
# 4    rikitea           8      PF  1534986579       100 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     77.00       11.41
# 1     50.00       13.87
# 2     66.20        5.82
# 3     77.00        8.05
# 4     69.58       19.71

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_df.plot.scatter(x = "Latitude", y = "Temperature (F)", color = "blue", 
                        alpha = 0.75, edgecolors = "k", linewidths = 1)
plt.grid()
plt.title("Latitude vs. Temperature (9/28/2018)")
plt.savefig("../Latitude vs. Temperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
weather_df.plot.scatter(x = "Latitude", y = "Humidity (%)", color = "coral", 
                        alpha = 0.75, edgecolors = "k", linewidths = 1)
plt.grid()
plt.title("Latitude vs. Humidity (9/28/2018)")
plt.savefig("../Latitude vs. Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
weather_df.plot.scatter(x = "Latitude", y = "Cloudiness (%)", color = "red", 
                        alpha = 0.75, edgecolors = "k", linewidths = 1)
plt.grid()
plt.title("City Latitude vs. Cloudiness (9/28/2018)")
plt.savefig("../Latitude vs. Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
weather_df.plot.scatter(x = "Latitude", y = "Wind Speed (mph)", color = "green", 
                        alpha = 0.75, edgecolors = "k", linewidths = 1)
plt.grid()
plt.title("Latitude vs. Wind Speed (9/28/2018)")
plt.savefig("../Latitude vs. Wind Speed.png")
plt.show()
